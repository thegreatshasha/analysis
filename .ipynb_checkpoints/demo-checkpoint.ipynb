# %%
# Let's do g_r fluctuations movie

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines){
#     return false
# }

# %%
from utilities import *
from paircorrelation import pairCorrelationFunction_2D
import numpy as np
import matplotlib.pyplot as plt

densities = np.linspace(10,500,50).astype(int)

for density in densities:

    x = np.random.uniform(0, 20, density)
    y = np.random.uniform(0, 20, density)

    g_r, r, reference_indices = pairCorrelationFunction_2D(x, y, 20.0, 5, 0.1)

    plt.figure(figsize=(8,8))
    plt.plot(r, g_r, color='black')
    plt.xlabel('r')
    plt.ylabel('g(r)')
    plt.xlim( (0, 5) )
    plt.ylim( (0, 5))#1.05 * g_r.max()) )

    #plot_adsorbed_circles(x, y, 0.1, 20, reference_indices=reference_indices)
# Out:
# /home/alanrajjeffrey/.local/lib/python2.7/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
# Target: Generate g(r) transition plots. See the density morph into others.
# At the very least, that's a cool level1 statistical summary of this

# %%
g_r.shape
# Out:
# (51,)

# %%
import seaborn as sns
