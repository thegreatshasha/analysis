# %%
import glob
import numpy as np
from utilities import *
from paircorrelation import pairCorrelationFunction_2D
import matplotlib.pyplot as plt

# %%
detection_files = sorted(glob.glob('detections_csv/*'))[0:10]

for data_file in detection_files:
    print(data_file)
    plt.figure(figsize=(8,8))
    data = np.loadtxt(data_file, delimiter=',')

    x = data[:,0]
    y = data[:,1]

    g_r, r, reference_indices = pairCorrelationFunction_2D(x, y, 2000.0, 100, 5)

    plt.plot(r, g_r)
    #plt.show()
# Out:
# detections_csv/vid15_3500.csv
# detections_csv/vid15_3501.csv
# detections_csv/vid15_3502.csv
# detections_csv/vid15_3503.csv
# detections_csv/vid15_3504.csv
# detections_csv/vid15_3505.csv
# detections_csv/vid15_3506.csv
# detections_csv/vid15_3507.csv
# detections_csv/vid15_3508.csv
# detections_csv/vid15_3509.csv

# %%
sorted(glob.glob('detections_csv/*'))[1]
# Out:
# 'detections_csv/vid15_3501.csv'

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
plt.show()

ax = fig.add_subplot(111)

ax.plot(x,y)

# %%
x
# Out:
# array([1215.29184325, 1202.30047802, 1522.75247462, 1430.16211525,
#        1579.65098221, 1095.77860429, 1173.71030447, 1205.29251946,
#        1329.95894326, 1604.23630385, 1713.40035849, 1853.86964183,
#         586.27209275,  653.36005421,  717.90190987,  784.38537357,
#         509.17461897,  907.88007589,  871.93570301,  778.10676663,
#        1048.96711853, 1103.48544889, 1189.05019266, 1215.44030429,
#        1088.53098023, 1277.04734823, 1306.86465817, 1591.48076478,
#        1536.59563012, 1489.72975047, 1646.00840413, 1665.04141103,
#        1822.49770038, 1878.55707145,  480.68107378,  221.85731998,
#         314.05072742,  542.57786025,  589.82972067,  725.72561349,
#         798.31908549,  601.8119397 ,  876.94962325,  870.06941671,
#         984.93422281, 1132.83293978, 1080.70686656, 1185.10958175,
#        1199.79194823, 1358.02339136, 1505.45548512, 1591.59556614,
#        1297.67150187, 1669.08569521, 1592.92254789, 1752.05498924,
# ...
